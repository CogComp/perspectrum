# %%
import json 

# ignore these
EXCLUDE_SITES = ['debatewise', 'idebate', 'procon', 'debatepedia']

def site_excluded(url):
    for site in EXCLUDE_SITES:
        if site in url:
            return True
    return False

claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/perspectives_with_bing_raw.json"

import re 

sentences = []

def cleanPerspectve(p): 
    p1 = p.replace("&#39;", "'")
    p1_split = re.split(r"[-|\||...|•]", p1)
    max_p1 = max(p1_split, key=lambda x:len(x))
    
    return max_p1.strip()

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    cleaned = cleanPerspectve(title)
    #                 print(" Title -> " + cleaned)
                    sentences.append(cleaned)
    #                 print(" Snippet -> " + website['snippet'])


with open('/Users/daniel/ideaProjects/perspective/data/bing_output/perspectives_with_bing_raw_titles.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))

# %%
claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/perspectives_with_bing_raw.json"

from ccg_nlpy import remote_pipeline

pipeline = remote_pipeline.RemotePipeline(server_api='http://macniece.seas.upenn.edu:4001')

sentences = []

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    try: 
                        doc = pipeline.doc( website['snippet'])
                        # print(doc.get_lemma) # will produce (hello Hello) (, ,) (how how) (be are) (you you) (. .) (i I) (be am) (do doing) (fine fine)
        #                 if doc.get_sentences != None and doc.get_sentences.get_cons() != None: 
        #                 print(doc.get_sentences)
                        for s in doc.get_sentences().get_cons(): 
                            normalized = cleanPerspectve(s['tokens'])
                            if len(normalized.split(" ")) > 3 and len(normalized.split(" ")) < 12: 
    #                             print("snippet -> " + normalized)
                                sentences.append(normalized)
    #                 print(" Snippet -> " + website['snippet'])
                    except: 
                        print("something hapenned . . . ")

with open('/Users/daniel/ideaProjects/perspective/data/bing_output/perspectives_with_bing_raw_snippets.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))
# Out:
# INFO:ccg_nlpy.pipeline_config:Using pipeline web server with API: http://macniece.seas.upenn.edu:4001
# INFO:ccg_nlpy.remote_pipeline:pipeline has been set up
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .

# %%
claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/evudences_with_bing_raw.json"

sentences = []

def cleanPerspectve(p): 
    p1 = p.replace("&#39;", "'")
    p1_split = re.split(r"[-|\||...|•]", p1)
    max_p1 = max(p1_split, key=lambda x:len(x))
    
    return max_p1.strip()

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    cleaned = cleanPerspectve(title)
    #                 print(" Title -> " + cleaned)
                    sentences.append(cleaned)
    #                 print(" Snippet -> " + website['snippet'])


with open('/Users/daniel/ideaProjects/perspective/data/bing_output/evidence_with_bing_raw_titles.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))

# %%
claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/evudences_with_bing_raw.json"

from ccg_nlpy import remote_pipeline

pipeline = remote_pipeline.RemotePipeline(server_api='http://macniece.seas.upenn.edu:4001')

sentences = []

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    try: 
                        doc = pipeline.doc( website['snippet'])
                        # print(doc.get_lemma) # will produce (hello Hello) (, ,) (how how) (be are) (you you) (. .) (i I) (be am) (do doing) (fine fine)
        #                 if doc.get_sentences != None and doc.get_sentences.get_cons() != None: 
        #                 print(doc.get_sentences)
                        for s in doc.get_sentences().get_cons(): 
                            normalized = cleanPerspectve(s['tokens'])
                            if len(normalized.split(" ")) > 3 and len(normalized.split(" ")) < 12: 
    #                             print("snippet -> " + normalized)
                                sentences.append(normalized)
    #                 print(" Snippet -> " + website['snippet'])
                    except: 
                        print("something hapenned . . . ")

with open('/Users/daniel/ideaProjects/perspective/data/bing_output/evidence_with_bing_raw_snippets.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))
# Out:
# INFO:ccg_nlpy.pipeline_config:Using pipeline web server with API: http://macniece.seas.upenn.edu:4001
# INFO:ccg_nlpy.remote_pipeline:pipeline has been set up
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .

# %%
claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/claims_with_bing_raw.json"

sentences = []

def cleanPerspectve(p): 
    p1 = p.replace("&#39;", "'")
    p1_split = re.split(r"[-|\||...|•]", p1)
    max_p1 = max(p1_split, key=lambda x:len(x))
    
    return max_p1.strip()

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    cleaned = cleanPerspectve(title)
    #                 print(" Title -> " + cleaned)
                    sentences.append(cleaned)
    #                 print(" Snippet -> " + website['snippet'])


with open('/Users/daniel/ideaProjects/perspective/data/bing_output/claim_with_bing_raw_titles.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))

# %%
claim_persp_path = "/Users/daniel/ideaProjects/perspective/data/bing_output/claims_with_bing_raw.json"

from ccg_nlpy import remote_pipeline

pipeline = remote_pipeline.RemotePipeline(server_api='http://macniece.seas.upenn.edu:4001')

sentences = []

with open(claim_persp_path, 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
#         print("*" + x["title"])
        # print(json.dumps(x["bing"]))
        if "bing" in x and "webPages" in x["bing"]: 
            for website in x["bing"]["webPages"]["value"]:
                url = website["url"]
                # print(website.keys())
                title = website["name"]
                if site_excluded(url):
                    continue
                else:
                    try: 
                        doc = pipeline.doc( website['snippet'])
                        # print(doc.get_lemma) # will produce (hello Hello) (, ,) (how how) (be are) (you you) (. .) (i I) (be am) (do doing) (fine fine)
        #                 if doc.get_sentences != None and doc.get_sentences.get_cons() != None: 
        #                 print(doc.get_sentences)
                        for s in doc.get_sentences().get_cons(): 
                            normalized = cleanPerspectve(s['tokens'])
                            if len(normalized.split(" ")) > 3 and len(normalized.split(" ")) < 12: 
    #                             print("snippet -> " + normalized)
                                sentences.append(normalized)
    #                 print(" Snippet -> " + website['snippet'])
                    except: 
                        print("something hapenned . . . ")

with open('/Users/daniel/ideaProjects/perspective/data/bing_output/claim_with_bing_raw_snippets.txt', 'w') as the_file:
    the_file.write("\n".join(sentences))
# Out:
# INFO:ccg_nlpy.pipeline_config:Using pipeline web server with API: http://macniece.seas.upenn.edu:4001
# INFO:ccg_nlpy.remote_pipeline:pipeline has been set up
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .
# something hapenned . . .

# %%
# convert the text file into a json file 
with open("/Users/daniel/ideaProjects/perspective/data/bing_output/tobemerged/merged_file.txt") as fp: 
    lines = fp.readlines()

data = []
for l in lines: 
    data.append({"sent": l})
    
with open('/Users/daniel/ideaProjects/perspective/data/bing_output/tobemerged/merged_file.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
# dropping the unique sentence from the list of statements 
with open("/Users/daniel/ideaProjects/perspective/data/internet_claims/controversial_claims.txt") as fp: 
    lines = fp.readlines()
print(len(lines))
lines = [x for x in list(lines) if x.strip()[-1] != '?']
sorted_unique_lines = sorted(list(set(lines))) 
print(len(sorted_unique_lines))

with open('/Users/daniel/ideaProjects/perspective/data/internet_claims/controversial_claims_unique_sorted.txt', 'w') as the_file:
    the_file.write("".join(sorted_unique_lines))

# %%
claim_top_topic_map = {}
with open("/Users/daniel/ideaProjects/perspective/experiment/claims_with_topics.json", 'r', encoding='utf-8') as fin:
    claim_topics = json.load(fin)
    for i, x in enumerate(claim_topics): 
        if 'noun_phrases' in x: 
#             print(str([a[0] for a in x['noun_phrases'][0:5]]))
            claim_top_topic_map[x['claim_id']] = " ".join([a[0] for a in x['noun_phrases'][0:4]])
    
claim_top_topic_map
# Out:
# {1: 'children child performers the child example',
#  2: 'celebrities national service south korea the basis',
#  3: 'aid trade countries example',
#  4: 'schools the military students military recruitment',
#  5: 'murdoch rupert murdoch a fit person an international media corporation',
#  6: 'smoking smokers a ban restrictions',
#  7: 'rights animals interests the function',
#  8: 'pr parliament parties proportional representation',
#  9: 'curfews children a child curfews the police',
#  10: 'a graduated response copyrighted material unauthorised file-sharing consumers',
#  11: 'the internet a human right access a right',
#  12: 'freedom censorship human rights the right',
#  13: 'ratify the anti-counterfeiting trade agreement acta',
#  14: 'internet service the government governments grounds',
#  15: 'the internet internet governance cirp a new global body',
#  16: 'the net neutrality legislation',
#  17: 'public bodies a presumption favour publication',
#  18: 'football glt technology goal line technology',
#  19: 'drugs the use performance athletes',
#  20: 'humans the bull pain all nations',
#  21: 'instant replay umpires baseball major league baseball',
#  22: 'women violence music people',
#  23: 'the universe the cost the iss space',
#  24: 'gay couples a man marriage gay marriage',
#  25: 'the catholic church the church the use contraception',
#  26: 'god atheism the universe the existence',
#  27: 'the state anarchism a valuable political ideology nothing',
#  28: 'democracy government individuals the country',
#  29: 'capitalism socialism form the economy',
#  30: 'the icc the international criminal court the prosecutor the rome statute',
#  31: 'the eu a common eu foreign policy world politics tests',
#  32: 'the world the eu the security council the united nations security council',
#  33: 'smokers healthcare access people',
#  34: 'smoking smokers this ban human rights',
#  35: 'cannabis the effects july 20 2011 people',
#  36: 'blasphemy',
#  37: 'hip hop music lyrics violent and criminal lifestyles',
#  38: 'the military anat kamm the leaking military documents',
#  39: 'extremist websites the internet users prison',
#  40: 'the satanic verses india ’s ban india speech',
#  41: 'corporations ’ use ip laws relation event sponsorship',
#  42: 'the internet the power government a means',
#  43: 'religious freedom human rights one the primary foreign policy concerns',
#  44: 'the bbc the broadcast art blaspheme',
#  45: 'town centres town sense an out',
#  46: 'nuclear power the eu nuclear technology costs',
#  47: 'animals research performing tests humans',
#  48: 'private universities the uk universities the quality',
#  49: 'history schools the holocaust no place',
#  50: 'the state corporal punishment criminals the use',
#  51: 'the olympics a good investment the bidding process the ioc',
#  52: 'weekly working hours a legally mandated ceiling week the economy',
#  53: 'gambling people casinos gamblers',
#  54: 'violent video games parents their children the sale',
#  55: 'the prophet danish newspapers cartoons citizens',
#  56: 'the patient feed sufferers anorexia nervosa life',
#  57: 'english the official language the united states one',
#  58: 'museums origin artefacts cultural property residing',
#  59: 'wikipedia a force good the internet',
#  60: 'public service broadcasters example the bbc people',
#  61: 'violent video games the government violence the sale',
#  62: 'advertising people us example',
#  63: 'newspapers the past a newspaper people',
#  64: 'aboriginal culture the land indigenous populations example',
#  65: 'women sexist advertising advertising business',
#  66: 'the internet the holocaust the government access',
#  67: 'candidates the full financial history all candidates political office',
#  68: 'transparency security life operations',
#  69: 'the internet western democracies internet censorship oppressive regimes',
#  70: 'collisions baseball the plate the catcher',
#  71: 'the world cup fifa the winter one',
#  72: 'the international level sports international competitions professional sportsmen',
#  73: 'women all women shortlists positive discrimination parliament',
#  74: 'force the state human rights the use',
#  75: 'society affirmative action people the black experience',
#  76: 'illegal immigrants the road drivers licenses the streets',
#  77: 'china the one child policy the people the policy',
#  78: 'zero tolerance that zero tolerance policing a good tactic fighting crime',
#  79: 'self determination south ossetia georgia human rights',
#  80: 'self determination the republika srpska bosnia & herzegovina serbia',
#  81: 'pornography women the feminist movement a ban',
#  82: 'the cities developing nations restrictions rural-urban migration',
#  83: 'women gender quotas the eu gender equality',
#  84: 'youth spending young people money',
#  85: 'women countries the european union the eu',
#  86: 'guns teachers tteachers threats',
#  87: 'women combat a result example',
#  88: 'arranged marriages eu countries themselves people',
#  89: 'the reproductive health bill families and values poor families investment',
#  90: 'a child human cloning human dignity cloning',
#  91: 'return israel the palestinian right palestinians',
#  92: 'sexual orientation grounds asylum',
#  93: 'sex markets sexual services prostitution',
#  94: 'the right asylum democratic nations the language',
#  95: 'asbos the order anti-social behaviour orders uk',
#  96: 'university positive discrimination diversity affirmative action',
#  97: 'child soldiers the icc a defence “ cultural relativism ”',
#  98: 'an amnesty illegal immigrants',
#  99: 'children the sale ’s toys fast food meals',
#  100: 'migrants the world countries protection',
#  101: 'children countries people us',
#  102: 'children the society people today',
#  103: 'housewives women their work services',
#  104: 'social security twelve reasons a bad idea politicians',
#  105: 'passengers security airports israel',
#  106: 'couples their relationships the courts the division',
#  107: 'crimes crime enhancements hate crimes blacks',
#  108: 'the age consent laws the problem consent',
#  109: 'the mother partial birth abortions birth abortion',
#  110: 'marriage an outdated institution people the uk',
#  111: 'profiling terrorists racial profiling airport security checks',
#  112: 'feminism needed women the feminist cause',
#  113: 'countries an imbalanced male / female ratio males parents',
#  114: 'a child children parents heritable diseases',
#  115: 'campus hate speech expression ideas',
#  116: 'parents the sex their children a child',
#  117: 'patent genes people myriad your findings',
#  118: 'parents homosexuals children gay couples',
#  119: 'illegal immigrants repatriation the country all illegal immigrants',
#  120: 'racial quotas south african rugby quotas players',
#  121: 'south africa an olympics good factor africa',
#  122: 'gabon nations the africa cup a good thing',
#  123: 'restrictions overseas players football the quality',
#  124: 'playoffs the playoffs fans collegiate level american football',
#  125: 'ukraine prison boycott the euro 2012 yulia timoshenko',
#  126: 'athletes themselves ban countries very harsh training methods',
#  127: 'sport women men the media',
#  128: 'chess the olympics cheating an olympic sport chess',
#  129: 'men women sports leagues',
#  130: 'the developing world the developed world academic work countries',
#  131: 'any work a creative commons license the government the work',
#  132: 'tanks funding their funders a think tank',
#  133: 'ban all anonymous the internet',
#  134: 'us nothing surveillance privacy',
#  135: 'the united states indiscriminate nsa surveillance the rest the world',
#  136: 'facebook one touch the democratic process',
#  137: 'the right people the internet a person',
#  138: 'riots the police access sense',
#  139: 'the west uprisings anonymity western companies',
#  140: 'universities the state state funding all academic work',
#  141: 'online gambling money their citizens people',
#  142: 'access universities the university all academic work',
#  143: 'censorship human rights help internet censorship',
#  144: 'sanctions cyber attacks china the sanctions',
#  145: "their children parents 's online and mobile communications children",
#  146: 'private lives public figures scrutiny',
#  147: 'politicians privacy no right a right',
#  148: 'amnesty bloggers the west their native states',
#  149: 'the length copyright protection artists the products',
#  150: 'the sale surveillance technology non-democratic countries',
#  151: 'targeted online advertising the basis user profiles and demographics the voter',
#  152: 'the state the private sector broadband access',
#  153: 'the isps access extremist websites people',
#  154: 'companies the personal data their clients /',
#  155: 'art creative commons all literature photography , film and music',
#  156: 'states subsidise mother tongue education large immigrant groups',
#  157: 'african cities forced evictions africa slums',
#  158: 'women politics quotas senegal',
#  159: 'the government uganda its citizens lgbt rights',
#  160: 'creationism evolution schools life',
#  161: 'domestic intelligence agencies democracy a legitimate role the government',
#  162: 'intercept evidence evidence court wire-tapped and ‘ intercepted ’ evidence',
#  163: 'the internet internet anonymity the right anonymous',
#  164: 'people 3d printers a ban the sale',
#  165: 'technology africa entrepreneurialism youths',
#  166: 'an act war a large scale cyber a cyber attack',
#  167: 'male infant circumcision child abuse parents the light',
#  168: 'the sabbath a day rest people',
#  169: 'schools the veil the niqab and other face coverings women',
#  170: 'religion more harm good the world',
#  171: 'religious symbols division the hijab public buildings',
#  172: 'god belief all powerful the problem',
#  173: 'religious beliefs government laws',
#  174: 'the church the state england the uk',
#  175: 'one a world us the world',
#  176: 'museums visitors government funding all museums',
#  177: 'celibacy remove the requirement catholic priests a vow',
#  178: 'god allegiance the pledge the words',
#  179: 'a christian church the ordination gay and lesbian priests homosexuality',
#  180: 'students universities online courses moocs',
#  181: 'mobile phones tanzania ’s taxation a good model taxes',
#  182: 'africa high quality generic drugs generic drugs patented drugs',
#  183: 'germany german prosecutors nsa surveillance angela merkel',
#  184: 'animals us research ban animal testing',
#  185: 'us a mobile phone mobile phones children',
#  186: 'the moon earth the universe moon',
#  187: 'cars cell phones the use other distractions',
#  188: 'people the drug the right trials',
#  189: 'the united states nuclear weapons the development the technology',
#  190: 'music the artist permission theft',
#  191: 'students teachers social networking websites the law',
#  192: 'governments open source software microsoft software',
#  193: 'the internet the government censorship free speech',
#  194: 'manned space flight humanity space flight people',
#  195: 'intellectual property rights intellectual property firms resources',
#  196: 'selective breeding the development genetically modified organisms one',
#  197: 'evolution the bible creationism god',
#  198: 'google china its search results chinese internet freedom',
#  199: 'increased aid world countries large influxes immigrants',
#  200: 'the gulf states more syrian refugees isis refugees',
#  201: 'prison 18 jail cyberbullies',
#  202: 'a lack intellectual migration brain drain opportunities',
#  203: 'aid homosexuality african states cut aid',
#  204: 'migration africa free movement remittances',
#  205: 'housing slums african cities hazardous environments reports',
#  206: 'women the feminisation africa ’s labour force labour participation and rights labour participation',
#  207: 'poverty africa the most important security issue themselves',
#  208: 'civil society a wider participation africa ’s political life economic development',
#  209: 'women titles land titles land titling',
#  210: 'a referendum the public the referendum the uk',
#  211: 'stable democracies the arab spring revolutions the region themselves',
#  212: 'nuclear weapons states themselves a right',
#  213: 'the house lords the people reform',
#  214: 'mercenaries pmcs war iraq',
#  215: 'suspected terrorists force the use the event',
#  216: 'the right arms the lethal nature sports',
#  217: 'nato the eu libya the world',
#  218: 'government the market big and beefy home',
#  219: 'turkey the eu europe the european union',
#  220: 'faith schools normal schools creates animosity religious groups faith schools',
#  221: 'handguns the state the law dc',
#  222: 'drones war aerial vehicles terrorist targets',
#  223: 'corporations does campaign finance the united states speech',
#  224: 'drugs the war the united states the united states scale',
#  225: 'the united states foreign aid the foreign aid budget aid',
#  226: 'film stars music stars other popular entertainers party-political campaigns',
#  227: 'the u.s. government current levels taxes',
#  228: 'catalan an independence referendum a referendum self determination',
#  229: 'the people issues countries your representative',
#  230: 'abandon kofi annan ’s peace plan syria',
#  231: 'greece its debt and return the drachma the greek economy',
#  232: 'the new start treaty new start russia the treaty',
#  233: 'tibet the middle way the dalai lama the dalai lama ’s ‘ third way ’',
#  234: 'puerto rico the us puerto ricans puerto rico statehood united states council',
#  235: 'mayors the mayor city mayors councillors',
#  236: 'abolish the superdelegate system democratic party conventions candidates one',
#  237: 'quebec canada self determination the will',
#  238: 'opinion polls the democratic process public expression citizens',
#  239: 'kosovo serbia independence recognise kosovo',
#  240: 'hamas aid the eu , usa other western donors',
#  241: 'university university education the state free university education',
#  242: 'politicians prosecution a politician immunity',
#  243: 'the un israel a palestinian state the united states',
#  244: 'the us habeas corpus its allies restrict the right',
#  245: 'abandon the timetable withdrawal afghanistan',
#  246: 'ireland the republic cent a united ireland',
#  247: 'people the public sector the private sector workers',
#  248: 'violence the use truth and reconciliation commissions access',
#  249: 'negative campaigning politicians voters political campaigns',
#  250: 'referendums increased use the public issues',
#  251: 'the governance the united states the two major us political parties',
#  252: 'all u.s. presidential primaries the same day candidates state',
#  253: 'the u.s. hegemonic military power',
#  254: 'the us the u s libya congress',
#  255: 'socialism dead the left capitalism',
#  256: 'the use atomic bombs the us surrender',
#  257: 'the republican party its way the party the way',
#  258: 'the monarch abolish the monarchy monarchy one',
#  259: 'congress the commerce clause interstate commerce the constitution',
#  260: 'the electoral college voters the candidate abolish the us electoral college',
#  261: 'the uk scotland the scottish independence scots',
#  262: 'identification compulsory identity cards identity cards the scheme',
#  263: 'iraq the war the middle east the cost',
#  264: 'bribery corruption bribes companies',
#  265: 'nato russia nato membership georgia and ukraine',
#  266: 'the korean peninsula reunification china the population',
#  267: 'the u s cluster bombs the use the u.s.',
#  268: 'landmines usa the ottawa convention mines',
#  269: 'society a libertarian a state nature',
#  270: 'the united states nuclear weapons the us israel',
#  271: 'candidates open primaries elections parties',
#  272: 'russia strong leadership the strong leadership corruption',
#  273: 'earmarks congress abolish congressional earmarks politicians',
#  274: 'the geneva conventions terrorists war the war',
#  275: 'israel hamas gaza the palestinians',
#  276: 'nato the eu a single european union army the us',
#  277: 'syria the west assad invasion',
#  278: 'such a thing a just war',
#  279: 'terrorism violence innocent civilians that terrorism',
#  280: 'referendums the eu a referendum any new eu treaty',
#  281: 'tactical nuclear weapons nuclear weapons the united states themselves',
#  282: 'nuclear weapons abolish nuclear weapons the use the wrong hands',
#  283: 'republicans the economy deregulation the banking crises',
#  284: 'britain the euro money the euro currency',
#  285: 'term limits office the legislature government',
#  286: 'people compulsory voting voting politics',
#  287: 'self determination peoples the right self-determination',
#  288: 'federal states unitary nations citizens themselves',
#  289: 'troops the un a un standing army the united nations',
#  290: 'term limits power government leaders',
#  291: 'trial internment terror the war',
#  292: 'the world north korean provocations the regime north korea',
#  293: 'elections 16 one election different elections',
#  294: 'the people elections sham elections no elections',
#  295: 'africa us terrorist organisations these groups',
#  296: 'libya the western intervention a success gaddafi',
#  297: 'lesotho south africa sa the sa government',
#  298: 'labour a move the left the right',
#  299: 'the west islamic state / daesh the most significant threat daesh',
#  300: 'the death penalty prison execution life',
#  301: 'abortion the child conception the woman',
#  302: 'the government speech freedom times',
#  303: 'the people participatory democracy a good idea a system',
#  304: 'the right that person the state people',
#  305: 'vital organs the donor donations the expense',
#  306: 'important decisions children ’s health medical professionals their parents',
#  307: 'one the death killing the people',
#  308: 'capital punishment africa a culture the rule',
#  309: 'spill neo-functionalism the integration the european union',
#  310: 'fundamental human rights human rights a society universal benefits',
#  311: 'animals vegetarian meat one',
#  312: 'a flat tax their income the tax governments',
#  313: 'a criminal offence life human rights the human body',
#  314: 'the rich the future remove bush tax cuts the wealthy',
#  315: 'governments the free market',
#  316: 'a time assisted suicide society voluntary euthanasia',
#  317: 'terrorism civil liberties the threat the greater good',
#  318: 'jury trial juries jurors',
#  319: 'the eu the uk uk more influence',
#  320: 'the eu british security security the uk',
#  321: 'a referendum uk a second brexit referendum the eu',
#  322: 'syria weapons inspectors the path a point',
#  323: 'a leader african leaders their health the leader',
#  324: 'a democratic government democracy a military coup a coup',
#  325: 'crimea russia ukraine the right',
#  326: 'the g8 russia the biggest action the west',
#  327: 'russia ukraine crimea a lease',
#  328: 'the african union africa its pledge all war',
#  329: 'ariel sharon war crimes an international court',
#  330: 'eritrea its isolation hostile nations isolation',
#  331: 'good governance the prize africa governance',
#  332: 'morsi the egyptian army egypt egyptians',
#  333: 'oil a trust fund politicians put taxes / revenue',
#  334: 'mercenaries the prevalence ‘ african mercenaries ’ conflicts',
#  335: 'the state terrorists violence the terrorists',
#  336: 'the icc the syrian civil war chemical weapons individuals',
#  337: 'europe european parliament elections only one voting district separate country seats',
#  338: 'the eu scotland independence the best way',
#  339: 'turkey a democracy the akp democracy',
#  340: 'afghanistan nato the taliban the country',
#  341: 'mali france the conflict the french',
#  342: 'syria chemical weapons the world the use',
#  343: 'super pacs individuals anonymous contributions corporations and individuals',
#  344: 'the voting age 16 the vote governments',
#  345: 'a criminal dna database may 19 2011 samples suspects',
#  346: 'the double jeopardy rule us double jeopardy defendants',
#  347: 'drugs people cannabis the illegality',
#  348: 'minimum sentences mandatory sentencing prosecutors judges',
#  349: "students the victim 's death suicide",
#  350: 'limit prison violent offenders',
#  351: 'drug addicts needle exchanges drug use fund needle exchanges',
#  352: 'argentina the islands sovereignty the islanders',
#  353: 'rehabilitation society the offender criminal justice',
#  354: 'the defendant the justice system this motion a jury',
#  355: 'cultural heritage a crime humanity treat the desecration and destruction',
#  356: 'military action atrocities united nations security council approval self defence',
#  357: 'the icc create an african criminal court an african criminal court africa',
#  358: 'drugs guinea-bissau a front the us ’',
#  359: 'yanukovych the icc crimes ukraine',
#  360: 'the icc the court crimes child soldiers',
#  361: 'the icc africa the court war crimes',
#  362: 'the uhuru kenyatta indictment an unwelcome interference the icc kenya',
#  363: 'prosecutions the healing process crimes justice',
#  364: 'post conflict peace cannot impartial justice atrocities germany',
#  365: 'the icc african states africa an african criminal court',
#  366: 'the worst the death penalty the us capital punishment',
#  367: 'the government the population us the state',
#  368: 'state immunity head a good idea',
#  369: 'the icc criminal trials no exception evidence',
#  370: 'assault weapons the united states guns crime',
#  371: 'the icc trial the us the article 98 agreements',
#  372: 'the icc an icc enforcement arm its own enforcement arm international criminals',
#  373: 'the united states mexico ’s drugs war',
#  374: 'the media violent crimes people violent crime',
#  375: 'fines income the rich people',
#  376: 'social disgust art ideas legitimate grounds',
#  377: 'social deprivation crime people the family',
#  378: 'a legal qualification the cost a law degree partner',
#  379: 'drugs schools privacy the state',
#  380: 'china arms the european union its ban',
#  381: 'smoking films the depiction children',
#  382: 'coca leaf cocaine coca the coca leaf',
#  383: 'beauty contests women female beauty men',
#  384: 'war criminals justice victims the prosecution',
#  385: 'the schengen agreement the schengen area the eu europe',
#  386: 'darfur more the us the janjaweed',
#  387: 'detainees the guantanamo bay detention centre conditions the treatment',
#  388: 's m sadomasochism consent individuals',
#  389: 'israel the settlements peace settlements',
#  390: 'tibet the ttibet an independent state the tibetans',
#  391: 'the use the state corporal punishment adult offenders',
#  392: 'the client attorney client privilege attorney-client privilege their client',
#  393: 'the police themselves a good idea gun crime',
#  394: 'place cameras courtrooms televise court cases public reaction',
#  395: 'the un the united nations a responsibility human rights',
#  396: 'sanctions democracy a country themselves',
#  397: 'abolish the security council veto the p5 the security council the veto power',
#  398: 'russia the united states nato long term cooperation',
#  399: 'the taliban afghanistan the war iraq',
#  400: 'myanmar the us the eu the world',
#  401: 'obama rogue leaders preconditions',
#  402: 'europe the eu a federal europe the world',
#  403: "western states ' control the international monetary fund neoliberal foreign policy western dominance",
#  404: 'the americas the us countries workers',
#  405: 'the palestinian statehood the united nations general assembly palestine a legal entity',
#  406: 'the au africa the african union peace',
#  407: 'the poor poverty cash money',
#  408: 'the yasukuni shrine a visit japan yasukuni',
#  409: 'development the country democracies a dictatorship',
#  410: 'electricity build the grand inga dam the congo the country',
#  411: 'africa influence the continent an au force',
#  412: 'ethiopia a dam the dam the river nile',
#  413: 'africa china the continent hdi indicators',
#  414: 'cyber attacks create an international treaty / ban cyber-attacks china',
#  415: 'the icc the us and israel the international criminal court states',
#  416: 'cap eu the eu the common agricultural policy',
#  417: 'all veto powers individual eu member states greece unanimity requirement',
#  418: 'the eu a trade bloc a political union the european union',
#  419: 'india development aid 1 the same amount',
#  420: 'the rebels syria the world arms',
#  421: 'offence journalists news organisations news',
#  422: 'the admission turkey the eu',
#  423: 'the european union the eu countries example',
#  424: 'israel its pre-1967 borders the 1967 borders east jerusalem',
#  425: 'the world the collapse the state other countries',
#  426: 'the united nations the un countries wars',
#  427: 'reparations former colonial powers former colonies colonisation',
#  428: 'nato russia nato expansion eastern europe',
#  429: 'a constitution europe the ecj the eu',
#  430: 'world government a world government the citizens community',
#  431: 'jerusalem israeli society human rights the right',
#  432: 'offshoring demand a good idea developed economies',
#  433: 'the pipeline a good idea the keystone xl pipeline oil',
#  434: 'cuba sanctions the sanctions the united states',
#  435: 'britain the rebate the eu its eu rebate',
#  436: 'the eu switzerland and norway their neutrality the eu shares',
#  437: 'a single working language the eu english the european union',
#  438: 'the european parliament the sovereign law-making body eurozone states',
#  439: 'peace the conflict israel and palestine a two-state solution',
#  440: 'oda foreign development aid aid nations',
#  441: 'the us the united states a ‘ benign ’ hegemon an empire',
#  442: 'the un the united nations budget the united states the us',
#  443: 'grant the eu a permanent seat the un security council the united nations',
#  444: 'the developed world african climate adaptation the responsibility the ipcc',
#  445: 'private sector involvement healthcare africa the privatisation',
#  446: 'access the ‘ ’',
#  447: 'the democratic republic congo the un intervention a success',
#  448: 'men family planning the key uganda',
#  449: 'governments an ‘ open sky ’ agreement africa terrorism terror',
#  450: 'smoking public places africa ghana ’s ban',
#  451: 'the outcome the paris climate conference an international treaty binding emission cuts',
#  452: 'this policy organs deny non-donors',
#  453: 'children sex education schools',
#  454: 'require the provision cannabis any state medical program',
#  455: 'food people consumers labels',
#  456: 'introduce a “ fat tax ” obesity costs a fat tax',
#  457: 'provide breakfast all school students a school breakfast the day',
#  458: 'women the media a ban women ’s bodies',
#  459: 'the ban the market new york city the right',
#  460: 'diets us the promotion a diet',
#  461: 'alternative medicine a threat public health patients',
#  462: 'universal healthcare there mut a system one',
#  463: 'trans fats the government us the use',
#  464: 'patients consumers advertising drugs',
#  465: 'employers employees the interests their hiv status',
#  466: 'the body multiple vaccines the immune system children',
#  467: 'alcohol ban alcohol the problem alcohol abuse',
#  468: 'a fat tax the government us lmplement a fat tax',
#  469: 'schools one ban junk food our kids',
#  470: 'a ‘ wall ’ the shared usa and mexico border people the border',
#  471: 'skin whitening creams african nations the sale similar products',
#  472: 'women africa the key africa ’s economic future',
#  473: 'cape verde ’s regional future europe africa',
#  474: 'the seychelles climate change territory and relocate land',
#  475: 'limited press and speech freedom progress rwanda',
#  476: 'taiwan sao tome relations favour',
#  477: 'widen the east african community the region education troops',
#  478: 'spain melilla ceuta morocco',
#  479: 'the vdp zambia access mobile clinics',
#  480: 'tunisia economic growth tourism produces employment tourism',
#  481: 'the chagos islands mauritius',
#  482: 'teachers the lack investment the greatest barrier',
#  483: 'nollywood africa perceptions an effective instrument',
#  484: 'animals africa african governments tougher protections',
#  485: 'natural resources africa the government africans',
#  486: 'borders african borders ethnic groups african unity',
#  487: 'the un veto power africa an african country',
#  488: 'sex work sex workers legalize sex work controls',
#  489: 'a journalist assange journalism julian assange',
#  490: 'expression offence freedom muslims',
#  491: "a nation 's history and mythology its national security national security",
#  492: 'money speech the expenditure ideas',
#  493: 'nuclear waste a leak store nuclear waste nuclear material',
#  494: 'a carbon tax carbon emissions a cap-and-trade system companies',
#  495: 'the eu nuclear energy',
#  496: 'climate change adaptation the most urgent response the pressure',
#  497: 'school uniforms children parents uniforms',
#  498: 'school children parents their children',
#  499: 'the child vaccination the state children',
#  500: 'introduce year round schooling students summer holidays extra curricular activities',
#  501: 'the sat standardized tests the result the test',
#  502: 'the arts degrees the creative arts society',
#  503: 'school the school age education',
#  504: 'university fewer people people themselves',
#  505: 'mathematics a compulsory schools',
#  506: 'homework time a waste students',
#  507: 'schools poetry pupils people',
#  508: 'a graduate tax higher education a person the system',
#  509: 'a voucher scheme fund education their children the voucher scheme',
#  510: 'the child a child the parents parents',
#  511: 'foreign languages english languages countries',
#  512: 'private education private schools students state schools',
#  513: 'school the school education age',
#  514: 'sex sex education parents sexuality',
#  515: 'homework students ban homework school',
#  516: 'build a third heathrow runway its position a hub airport expansion',
#  517: 'the animal animals stunning ban the slaughter',
#  518: 'future generations the exploitation the arctic region the arctic',
#  519: 'animals the animals objects ban the use',
#  520: 'electricity build hydroelectric dams hydroelectric dams the environment',
#  521: 'wind power a primary focus future energy supply nuclear',
#  522: 'nuclear waste a leak countries store nuclear waste',
#  523: 'nuclear power invest renewable technologies the nuclear industry',
#  524: 'endangered species humans species laws',
#  525: 'community radio democracy voices control',
#  526: 'public display ‘ the spear ’ the process public decency freedom',
#  527: 'creationism teachers evolution freedom',
#  528: 'schools versions history us',
#  529: 'the darker side the nation history the formation',
#  530: 'rumours politicians',
#  531: 'putin pussy riot the imprisoned members political prisoners',
#  532: 'corporations free speech the ability profit',
#  533: 'western universities satellites states respect free speech',
#  534: 'the state bavaria the decision mein kampf',
#  535: 'free speech braille protect braille respect',
#  536: 'penalise religious hate speech the views freedom speech',
#  537: 'the media a celebrity celebrities allow celebrities',
#  538: "the enemies one 's nation legitimate free speech",
#  539: 'the right newspapers mistakes natural justice',
#  540: 'blasphemy no place the statute books the courts',
#  541: 'the cross work the case christians',
#  542: 'the state higher education university universities',
#  543: 'a loss retailers prices loss leaders',
#  544: 'teachers pay state school teachers merit an incentive',
#  545: 'prioritize the budget deficit domestic spending money',
#  546: 'institute a mandatory retirement age the number individuals the life expectancy',
#  547: 'the public sector people the case workers',
#  548: 'remittances replace aid poverty aid',
#  549: 'young people people 25 the government',
#  550: 'the uk the european union the eu the british economy',
#  551: 'hand the raising business and labour standards a prerequisite',
#  552: 'the hyperloop the pods themselves 1 35million',
#  553: 'subsidies the state these communities subsidize poor communities',
#  554: 'the minimum wage workers a minimum wage work',
#  555: 'the american jobs act the act the rich america',
#  556: 'high speed rail the u s create a national high speed rail system the u.s',
#  557: 'sovereign wealth funds countries the activities swfs',
#  558: 'the state more the wealthy taxation',
#  559: 'grey goods allow retailers resale " grey " goods abroad',
#  560: 'degree level the economy the state education compulsory',
#  561: 'compensation cultural appropriation people their culture',
#  562: 'violent video games video games children aggression',
#  563: 'golf a sport a game one',
#  564: 'the united states drone strikes us al qaeda',
#  565: 'abortion women abortions an abortion',
#  566: 'children vaccines measles the united states',
#  567: 'social security private accounts the trust funds people',
#  568: 'marriage gay marriage children same sex couples',
#  569: 'd a r e students drug use the program',
#  570: 'the ground zero mosque the world trade center site ground zero a muslim community center',
#  571: 'teachers tenure firing easier assignments',
#  572: 'dtc prescription drug ads patients prescription drugs consumers',
#  573: 'ronald reagan a good president taxes reagan tax revenues',
#  574: 'health care a right the united states a universal right',
#  575: 'obesity a disease other diseases the normal functioning',
#  576: 'the minimum wage the federal minimum wage an hour 7 25',
#  577: 'jobs companies the corporate tax rate the federal corporate income tax rate',
#  578: 'college graduates college high school graduates college degrees',
#  579: 'animals humans animal testing animal experiments',
#  580: 'a concealed handgun adults the right americans',
#  581: 'a vegetarian diet meat people a peer',
#  582: 'churches temples mosques synagogues',
#  583: 'the use standardized tests education america',
#  584: 'tablets students student textbooks',
#  585: 'social media people facebook social media sites',
#  586: 'school uniforms students uniforms schools',
#  587: 'marijuana legalization recreational marijuana the united states',
#  588: 'clinton office 1993 1999',
#  589: 'guns the united states children 100 000 people',
#  590: 'a gold standard the united states gold the gold standard',
#  591: '21 alcohol mlda 21 the drinking age',
#  592: 'college football the bowl championship series bcs teams',
#  593: 'cuba the embargo the united states the cuban government',
#  594: 'human activity global warming the atmosphere co2',
#  595: 'cell phones cell phone radiation rf radiation brain tumors',
#  596: 'universal basic income the poor poverty people',
#  597: 'bankruptcy student loan debt tuition colleges',
#  598: 'school vouchers students private schools public schools',
#  599: 'the penny pennies circulation time',
#  600: 'net neutrality the internet isps consumers',
#  601: 'homework students school high school students',
#  602: 'bottled water water the ban the university',
#  603: 'sanctuary cities san francisco people the united states',
#  604: 'police body cameras officers body cameras police officers',
#  605: 'the olympics the olympic games residents the city',
#  606: 'the national anthem kaepernick stand protest',
#  607: 'hockey fighting fans the game',
#  608: 'the electoral college the united states the popular vote presidential elections',
#  609: 'daylight saving time the united states the risk dst',
#  610: 'corporal punishment children k-12 schools the american academy',
#  611: 'books parents people kids',
#  612: 'a minimum weight limit professional models size zero models size zero',
#  613: 'christmas commercialization festivals and holidays jesus',
#  614: 'the money the olympics money our olympic medal count',
#  615: 'google the world the acting the extremely reliable source',
#  616: 'companies alternative interview methods skills the job',
#  617: 'internet use and misuse your eyes the internet',
#  618: 'the balance power europe the eighteenth century',
#  619: 'women men the front line afghanistan',
#  620: 'murder a defence society genetics',
#  621: 'a government the obligation the economic gap its rich and poor citizens',
#  622: 'hillary hillary clinton america clinton',
#  623: 'public transport people free money',
#  624: 'gm foods people scientists gm crops',
#  625: 'terms aa the country the past',
#  626: 'the world the country 1-child policy every single country',
#  627: 'deadly force victims the victim justice',
#  628: 'new nuclear power plants britain energy power stations',
#  629: 'aids all patents anti-retroviral drugs a cure',
#  630: 'university university education one an individual',
#  631: 'civil disobedience the law justified one',
#  632: 'the falklands argentina the people the british',
#  633: 'nuclear weapons terrorists states a nation',
#  634: 'the voting age 16 yes 16 year olds',
#  635: 'the eu turkey time these states',
#  636: 'students persistent bullies school a child',
#  637: 'kids the parents their parents a child',
#  638: 'school schools students games',
#  639: 'the prohibition drugs n’t work',
#  640: 'exams homework examinations a fair way',
#  641: 'uniforms school uniforms mandatory skirts',
#  642: 'people things their jobs an employee',
#  643: 'wikileaks the law a non-profit organization transparency',
#  644: 'baby ear piercing',
#  645: 'japan us military bases world war 2',
#  646: 'abortion further restricted or banned',
#  647: 'people public transport the recession businesses',
#  648: 'power b two dimensions china',
#  649: 'the right happiness the eu society',
#  650: 'nuclear weapons the spread more both sides',
#  651: 'speed cameras cameras accidents the money',
#  652: '16 year olds presidental elections adults children',
#  653: 'israel mossad extrajudicial killings foreign relations reputation',
#  654: 'international adoption',
#  655: 'google us',
#  656: 'men women society positive discrimination',
#  657: 'the ussr gorbachev the system socialism',
#  658: 'hacking justified the internet freedom',
#  659: 'children less time outdoors the physical and emotional wellbeing a child',
#  660: 'china more control its own seas sovereignty',
#  661: 'white tigers captivity people the breeding',
#  662: 'facebook people the information children',
#  663: 'animals zoos these animals wild animals',
#  664: 'schools the armed forces the army the world',
#  665: 'international students uk universities tuition fees home students',
#  666: 'science us morality human values',
#  667: 'intelligence agencies law evidence courts',
#  668: 'us origin artefacts the world',
#  669: 'music money people a job',
#  670: 'shakespeare the teaching compulsory his works',
#  671: 'tax cuts government spending the best way recession',
#  672: 'books children content warnings strong language',
#  673: 'christianity the catholic church mexican culture the introduction',
#  674: 'the death penalty terrorist acts the person acts',
#  675: 'housewives their children children more responsible mothers',
#  676: 'public high school students the united states standardized exit exams graduate',
#  677: 'prescription drugs the nhs prices medication',
#  678: 'terrorists the geneva conventions the geneva convention reciprocity',
#  679: 'mixed martial arts ufc a form human cockfighting',
#  680: 'sweden socialism the world the government',
#  681: 'direct vs. representative democracy',
#  682: 'inheritance tax income tax their children people',
#  683: 'british atrocities the blood its empire the government',
#  684: 'america universal healthcare research lack',
#  685: 'reality tv people the house shilpa',
#  686: 'background checks parents the right their children',
#  687: 'a safer world unilateral nuclear disarmament the best way nuclear weapons',
#  688: 'any job no job council tax account',
#  689: 'the world vegan a vegan diet meat',
#  690: 'the capitalist capitalism the rich the poor',
#  691: 'maths a compulsory gcse mathematics',
#  692: 'football video replays the game the match officials',
#  693: 'aid africa moyo people',
#  694: 'bottled water time travellers water',
#  695: 'the root money all evil no such thing',
#  696: 'the civil procedure rules a ‘ fair trial ’ the cpr parties',
#  697: 'illegal downloaders the internet internet connections this plan',
#  698: 'politics a celebrity a good minister celebrities',
#  699: 'children violence other adult contents dvd s',
#  700: 'politics people voting compulsory',
#  701: 'the catholic church the pope priests reform',
#  702: 'books vs tv tv wins',
#  703: 'london madrid cheap flights more harm',
#  704: 'your spouse ’s email account hacking trust married your life',
#  705: 'animals privacy humans the animal',
#  706: 'people who plea more lenient sentences',
#  707: 'man climate change a myth science',
#  708: 'people swearing the police a law',
#  709: 'people organ donation organ donors an organ donation scheme',
#  710: 'sports initiations this type peer pressure behaviour',
#  711: 'the monarchy britain the royal family monarchy',
#  712: 'access contraception the number teenage pregnancies',
#  713: 'too much importance correct spelling and grammar the language mistakes',
#  714: 'liberal democracies people ’s non-democracies south korea',
#  715: 'mother nature rule the world mother nature us',
#  716: 'scientology the church the majority my left',
#  717: 'iraq kuwait the us the coalition',
#  718: 'this house would arrest batman',
#  719: 'g20 – a waste time',
#  720: 'two children people more than two children children',
#  721: 'historical importance preservation only buildings sites',
#  722: 'tuition fees the government people a higher education',
#  723: 'absolute monarchy limited monarchy',
#  724: 'the eu power national governments the european union',
#  725: 'south korea the united states north korea support',
#  726: 'discipline schools needs schools the majority',
#  727: 'deny organ transplants people registered donors',
#  728: 'the united states ’ role the vietnam war an unnecessary step the fight',
#  729: 'children and not',
#  730: 'transport the best mode the future a train',
#  731: 'the national curriculum the capacity the way the ability',
#  732: 'the burning holy books',
#  733: 'wind farms a good solution the energy crisis wind',
#  734: 'a creature the street external factors animals',
#  735: 'compulsory mothers women breast feeding',
#  736: 'the grammar school system the uk children grammar schools',
#  737: 'slang young people potential employers the future people',
#  738: 'the eu farmers the amount agricultural production subsidies',
#  739: 'the school sikh school pupils ceremonial daggers an atmosphere',
#  740: 'calzaghe one joe joe calzaghe',
#  741: 'utility philosophy – utilitarianism n’t fair',
#  742: '“ specialists more generalists',
#  743: 'national service young people conscription people',
#  744: 'the glass ceiling women the percentage 60',
#  745: 'religion people us god',
#  746: 'parents neglect obesity obese children',
#  747: 'knife crime romeo and juliet the play teenagers',
#  748: 'the use mobile phones active social life an addiction',
#  749: 'the premier league the champions league the premiership the world',
#  750: 'books some point e books a laptop',
#  751: 'parents young people home back option',
#  752: 'sharks shark fin soup the shark a ban',
#  753: 'drug addicts society more compassion drug users',
#  754: 'home an office the office companies',
#  755: 'celebrities drug-related offences non-celebrities one',
#  756: 'global warming an issue the amount the need',
#  757: 'personality ability people a person',
#  758: 'world war iii too many pacts such a war the fact',
#  759: 'football us immigration france',
#  760: 'artificial happy endings a story completely ruins fairy tales a film',
#  761: 'women atheist atheist countries the countries',
#  762: 'the muslim people government their own it',
#  763: 'most people a little bit gay people',
#  764: 'universities graduates a job',
#  765: 'cyber stalking its consequences',
#  766: 'people their own organs organs poverty',
#  767: 'china north korea the people the prc',
#  768: 'people increased taxes america common programs',
#  769: 'people healthy eating mandatory the results',
#  770: 'game strategies cooperation vs competition',
#  771: 'an effective state high taxes people the taxes',
#  772: 'corporations a threat human rights us',
#  773: 'make-up us animal products alcohol',
#  774: 'contact aliens us earth',
#  775: 'the welfare system people a negative income-tax model the state',
#  776: 'money beggars the money drugs',
#  777: 'sunbeds unmanned salons day horror stories',
#  778: 'governments wealth redistribution ahead wealth creation wealth',
#  779: 'the rate physical fitness mental fitness mental health',
#  780: 'speed limits the government people cars',
#  781: 'unjust laws nazi germany jewish shops german people',
#  782: 'representative democracy direct democracy a better form government',
#  783: 'the world cup south africa the event the cost',
#  784: 'compensation climate change the compensation individual countries',
#  785: 'neil armstrong the moon the usa every incentive',
#  786: 'music that glorifies crime children ban glorifies crime',
#  787: 'the uk truly a democracy people a democracy',
#  788: 'food supermarkets people theft',
#  789: 'forced marriage forced marriages the wedding marriage',
#  790: 'anti-social behaviour orders',
#  791: 'the media the public problems the media ’s selective coverage',
#  792: 'people school teachers the right to punish pupils',
#  793: 'female children more useful home',
#  794: 'sports about making money the fans one',
#  795: 'junk food one schools students',
#  796: 'children lack parental guidance violent',
#  797: 'fast food advertising its a business a business its job',
#  798: 'rewards motivate students students rewards very specific conditions',
#  799: 'children religious education a part the school curriculum',
#  800: 'an option dropout highschool',
#  801: 'reality tv shows an important part popular culture today',
#  802: 'refugees developed countries accept more refugees many refugees',
#  803: 'a world water crisis the world water water scarcity',
#  804: 'competition the long the community gre issue',
#  805: 'the evil men lives the good',
#  806: 'wikileaks a threat national security the rest',
#  807: 'the iphone the blackberry people apple',
#  808: 'television us one the most effective mediums',
#  809: 'dna testing the money the cost a report',
#  810: 'social media school the curriculum children',
#  811: 'people individuals a moral obligation someone needs',
#  812: 'chocolate the sugar more chocolate our teeth',
#  813: 'britain a republic most other countries europe',
#  814: 'people their own bodies informed decisions their bodies',
#  815: 'the ozone layer',
#  816: 'christmas the true meaning people the people',
#  817: 'electronic tags a good idea prison people',
#  818: 'the law self defence people a knife',
#  819: 'women gender equality the women men stippers porn',
#  820: 'football the game the world goal line technology',
#  821: 'german unification a success the left party people',
#  822: 'the microwave reheat tea the kettle tea',
#  823: 'sanctions countries the world the un',
#  824: 'children politics school',
#  825: 'nuclear weapons the right the world the usa',
#  826: 'the host city stop the olympic games the olympic games peace and togetherness',
#  827: 'id cards people the uk the national identity scheme',
#  828: 'the opposition the gap the wealth gap progressive tax',
#  829: 'people multiculturalism example their cultures',
#  830: 'universities university students money',
#  831: 'education their children the private education system abolished',
#  832: 'pmcs the united states iraq private contractors',
#  833: 'nuclear weapons all nuclear weapons one the use',
#  834: 'the constitution constitutions special recognition the country',
#  835: 'co2 not cause global warming one plants',
#  836: 'the minimum driving age 18 accidents the accidents',
#  837: 'cars people cbd cbds',
#  838: 'prostitution prostitutes sex workers people',
#  839: 'compensation people the government governments',
#  840: 'the war the ‘ war terror ’ themselves',
#  841: 'violence violent video games video games violent crime',
#  842: 'prostitution the law prostitutes drugs',
#  843: 'pm unsc countries the unsc',
#  844: 'children the child a child the parent',
#  845: 'transgenic animals animals nt genes',
#  846: 'sharia law sharia britain muslims',
#  847: 'smoking public places smokers non smokers',
#  848: 'alcohol the age the law people',
#  849: 'an english parliament england the other home nations matters',
#  850: 'christianity the greatest deception a deception today',
#  851: 'the middle east foreign policy resources a negative influence',
#  852: 'the media the government governments hostage-taking',
#  853: 'terrorism publicity the public terrorists',
#  854: 'physical education schools sport compulsory',
#  855: 'plastic bags people the streets a time',
#  856: 'basic income tax income tax the economy renewable energy',
#  857: 'no coincidence the uk britain the eu',
#  858: 'this kind weapons weapons systems combat',
#  859: 'smoking people illegal cancer',
#  860: 'creationism fact science lessons school science lessons',
#  861: 'religion people war the world',
#  862: 'free press democracy press freedom no free press',
#  863: 'the debts all third world debt countries the population',
#  864: 'hiv hiv / aids compulsory testing people',
#  865: 'india kashmir the roma the roma people',
#  866: 'economic sanctions achieve foreign policy objectives',
#  867: 'a job people job seekers allowance their benefits',
#  868: 'democracy the executive the people the best form',
#  869: 'children the right to vote elections politics',
#  870: 'cctv freedom a threat our freedom',
#  871: 'boys schools more aggressive violent boys schools boys',
#  872: 'alcohol parents children moderation',
#  873: 'question authorities the authority authority school',
#  874: 'space military purposes hundreds military reconnaissance observation satellites',
#  875: 'ten commandments display schools the state',
#  876: 'museums people visitors “',
#  877: 'religious offence a civil offence',
#  878: 'newspapers a thing the past people',
#  879: 'governments their way the recession the economy',
#  880: 'christmas a scam not a proper holiday these holidays',
#  881: 'russia democracy a land autocracy',
#  882: 'money undermines sport ’s values money sport sportsmen',
#  883: 'the eu a common immigration policy',
#  884: 'autism people rain man a person',
#  885: 'post office the government the banks the post office a government',
#  886: 'taxes people smoothies fruit juices',
#  887: 'schizophrenia environmental not genetic factors',
#  888: 'new years resolutions themselves isn t pressure',
#  889: 'prisoners the right to vote the crime the punishment',
#  890: 'people online education harm the internet',
#  891: 'police service uk the police guns',
#  892: 'the teacher s / the class adults aren t',
#  893: 'the key success entrepreneurship entrepreneur experience',
#  894: 'olympic sports mind sports such chess , quizzing and debating the world',
#  895: 'obama the things barack obama race',
#  896: 'summer holidays',
#  897: 'society people inherited wealth children',
#  898: 'the uk radical constitutional reform',
#  899: 'privacy and freedom security',
#  900: 'valentines day just a hallmark ploy the day the snobbery',
#  901: 'the book the rye a bad book salinger',
#  902: 'the illegality recreational drugs more harm good',
#  903: 'about population growth',
#  904: 'the threat climate change lack scientific understanding neither',
#  905: 'the eu a future encourages a single community',
#  906: 'people technological advancement materialistic society things',
#  907: 'barbie barbie dolls the world the mental image',
#  908: 'resources high taxes governments companies',
#  909: 'scotland independence the snp se england',
#  910: 'life euthanasia or mercy killing the opposition euthanasia',
#  911: 'patents money a year life-saving drugs',
#  912: 'the economy deregulation people tax cuts',
#  913: 'corporations corruption the corporation anti bribery laws',
#  914: 'the tax the opposition inheritance tax all taxes',
#  915: 'life other planets earth us',
#  916: 'the economy vouchers the unemployed benefits',
#  917: 'prisoners society justice death',
#  918: 'racial profiling people the police the immigrants',
#  919: 'hr the un human rights council hr abuse the unhrc',
#  920: 'charities the poor govt gov',
#  921: 'animal testing penicillin antibiotics cancer',
#  922: 'macs pcs a mac mac',
#  923: 'parents teens their parents abortion',
#  924: 'the rich people the world tax',
#  925: 'the un meat consumption the eu the planet',
#  926: 'britain russia iswolsky individuals',
#  927: 'homework a limit the child him er',
#  928: 'martin luther king ’s dream ha',
#  929: 'our religion a person the right freedom',
#  930: 'climate change the world the end no it',
#  931: 'human rights aid tied the government',
#  932: 'a democracy all votes the vote the idea',
#  933: 'history a subject school the past',
#  934: 'the internet ’s anonymity people the internet scientific results',
#  935: 'gossip us all gossip the gossip market',
#  936: 'god life death hell',
#  937: 'painting mankind photography more than just vision paintings',
#  938: 'obese people countries a national health service higher taxes',
#  939: 'exams a bad idea knowledge revision',
#  940: 'the media youths a negative way',
#  941: 'romeo and juliet a tragedy moral condemnation the couple',
#  942: 'children part time and summer work money school',
#  943: 'school care school school day extended',
#  944: 'the criminal punishment the person less re offenders',
#  945: 'the internet internet privacy privacy online people',
#  946: 'such thing a glorious defeat',
#  947: 'teachers merit pay a good motivater teaching and test standards',
#  948: 'social networking sites the workplaces these sites a day',
#  949: 'the european union its member countries',
#  950: 'women the civil war the war the north',
#  951: 'america polls accurate predictors election results',
#  952: 'online shopping offline shopping online shopping',
#  953: 'genetic engineering humans',
#  954: 'lady macbeth macbeth the real driving force king duncan ’s murder',
#  955: 'gorbachev a key player the fall the berlin wall',
#  956: 'people gender equality men and women the same way',
#  957: 'paparazzi and press too much celebrities lives front',
#  958: 'language control thoughts our native language',
#  959: '7 a multiple verses the number',
#  960: 'space exploration a waste money the cost',
#  961: 'the proposition offshore drilling oil bp',
#  962: 'antartica the world antarctica resources',
#  963: 'animals meat humans us',
#  964: 'workers strikes employers strike',
#  965: 'polygamous marriage polygyny one the children',
#  966: 'women violence music society',
#  967: 'foreign workers the right local elections a voice',
#  968: 'a change a general election the nation parliamentary democracies',
#  969: 'nuclear reactor technology the export nuclear weapons an international ban',
#  970: 'adolf hitler not deserve his reputation evil hitler',
#  971: 'gb the us us guantanamo bay',
#  972: 'the state water the government a monopoly',
#  973: 'individuals fair use reasons the ip rights the internet',
#  974: 'pensions the government one the long',
#  975: 'their medals athletes the entire team dope',
#  976: 'children corporal punishment the child the person',
#  977: 'the legal age 16',
#  978: 'co-educational schools thbt boys girls serparatley',
#  979: 'the un reform too many countries more power',
#  980: 'the environment the economy air pollution even worse additional air traffic',
#  981: 'the government more money science',
#  982: 'new prisons overcrowding more prisons prisons',
#  983: 'university or college people nothing themselves',
#  984: 'schools illegal drug abuse teenagers',
#  985: 'job applicants their spent criminal convictions care services that person',
#  986: 'deregulation society',
#  987: 'mental ‘ illness ’ a socially constructed',
#  988: 'all time the best laver the grand slam',
#  989: 'children parents the government the child',
#  990: 'interest rates personal lending law 20 %',
#  991: 'people these organizations these groups the display',
#  992: 'human rights us people instance',
#  993: 'drugs the opposition people themselves',
#  994: 'mexico free trade fta the opposition',
#  995: 'the proposition liver transplants people the doctors',
#  996: 'god a god life people',
#  997: 'people the fact pre nups the state',
#  998: 'same sex marriage marriage homosexuality the opposition',
#  999: 'leaders countries extra-territorial rendition war crimes',
#  1000: 'compulsory immunization public health concerns a herd immunity the jab',
#  ...}

# %%
# try extracting similar sentences for each perspectives

import query_elasticsearch as es
import json         


def simplified_function(sent): 
    simplified = ''.join(x for x in sent if x.isalpha())
    return simplified.strip().lower()

# drop the repeated items 
def uniqueElements(items): 
    items_simple = set()
    selected = []
    for x in items: 
        sim_x = simplified_function(x[0])
        if sim_x in items_simple: 
            continue 
        else: 
            items_simple.add(sim_x)
            selected.append(x)
    return selected


output = []


with open("/Users/daniel/ideaProjects/perspective/data/pilot3_twowingos/110718-training-data/claim_perspective.json", 'r', encoding='utf-8') as fin:
    persps = json.load(fin)
    for i, x in enumerate(persps):
        id = x['id']
#         keywords = claim_top_topic_map[id]
        print("-------\n* Perspective + keywords: " + x['title']) # + " " + keywords 
        data = es.get_top_sentences(x['title'])
    #     print(json.dumps(data))
#         print(len(data))
        unique = uniqueElements(data)
#         for y in uniqueElements(data): 
#             print(y)
        output.append({"id": id, "title": x['title'], "sentences": unique})
            
with open('/Users/daniel/ideaProjects/perspective/data/relevant_senetences_to_perspectives/relevant_sentences_to_perspectives', 'w') as the_file:
    json.dump(output, the_file)
# Out:
# -------
# * Perspective + keywords: The use of child performers should be banned. Being a performer limits a child’s formal education
# -------
# * Perspective + keywords: The use of child performers should be banned. performers are at risk of exploitation
# -------
# * Perspective + keywords: The use of child performers should be banned. It is unethical to expose children to the pressures of performing
# -------
# * Perspective + keywords: The use of child performers should be banned. Being a performer can make the child physically vulnerable
# -------
# * Perspective + keywords: The use of child performers should be banned. Allowing children to perform pushes them to grow up too soon
# -------
# * Perspective + keywords: The use of child performers should be banned. Just as the state creates laws to protect child performers it could ban child performers
# -------
# * Perspective + keywords: The use of child performers should be banned. Child performers are necessary for roles in some films, television shows, etc., and for the survival of some sports
# -------
# * Perspective + keywords: The use of child performers should be banned. If child performers were banned, many children would find a way to perform illegally, now without legal protection.
# -------
# * Perspective + keywords: The use of child performers should be banned. The government has no right to prevent children from doing what they enjoy and are good at
# -------
# * Perspective + keywords: Celebrities should be exempt from National Service (in South Korea). Celebrities, like athletes, enhance the nation’s image and generate revenue
# -------
# * Perspective + keywords: Celebrities should be exempt from National Service (in South Korea). One of the great strengths of national service is that it demonstrates that everyone is equal
# -------
# * Perspective + keywords: Celebrities should be exempt from National Service (in South Korea). There are many professions that could more sensibly be given exemption such as teachers
# -------
# * Perspective + keywords: Trade is better than aid. Financial contributions from the West have proved detrimental for Africa.
# -------
# * Perspective + keywords: Trade is better than aid. Trade provides developing countries with an important basis for their own improvement.
# -------
# * Perspective + keywords: Trade is better than aid. Trade is a long-term basis for international co-operation.
# -------
# * Perspective + keywords: Trade is better than aid. Systemic aid' is detrimental to African society
# -------
# * Perspective + keywords: Trade is better than aid. Trade may not help those most in need.
# -------
# * Perspective + keywords: Trade is better than aid. Trade requires infrastructure
# -------
# * Perspective + keywords: Trade is better than aid. Free trade is dangerous
# -------
# * Perspective + keywords: Trade is better than aid. Trade does not allocate resources effectively
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. Young people should hear of the opportunities available in the armed services whilst in school
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. All high schools accepting state funding should accept military recruiters once a year
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. The purpose of the military entering schools is not solely recruitment but awareness
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. Young people are aware of the risks of military service and therefore would not be easily misled by military personnel
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. The military is an all-volunteer force and needs a percentage of school-age recruits each year
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. School children are too young to target for military service
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. Military recruiters downplay the risks of a military career, tempting schoolchildren into a career they would not have chosen with honest information.
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. Military recruitment in schools is less education than propaganda
# -------
# * Perspective + keywords: It should be allowed to have military recruitment in schools. Military recruitment in schools is illegal
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. Murdoch is morally unfit to run a powerful media company.
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. Lack of control
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. There was a lack of transparency in News Corp
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. Murdoch is effective at selling news
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. Having powerful media companies shields them from interference by governments.
# -------
# * Perspective + keywords: Rupert Murdoch is not a fit person to run an international media corporation. Murdoch does not seek to influence politics.
# -------
# * Perspective + keywords: Smoking should further be restricted. Restrictions benefit the health of third parties
# -------
# * Perspective + keywords: Smoking should further be restricted. The state has to take measures to protect the health of its citizens
# -------
# * Perspective + keywords: Smoking should further be restricted. Regulation harms safety and the poor population
# -------
# * Perspective + keywords: Smoking should further be restricted. Democratic systems should educate on smoking rather than restrict it
# -------
# * Perspective + keywords: Smoking should further be restricted. Smoking is a choice of lifestyle the government should not intervene with
# -------
# * Perspective + keywords: Animals have rights. Animals are intrinsically worthy of rights because they are sentient
# -------
# * Perspective + keywords: Animals have rights. Speciesism is wrong
# -------
# * Perspective + keywords: Animals have rights. Animals are equal to human beings.
# -------
# * Perspective + keywords: Animals have rights. Even if it matters whether or not humans and animals are similar, humans and animals are in fact similar enough that both should be granted rights.
# -------
# * Perspective + keywords: Animals have rights. Even if we did think that animals were less intelligent than humans beings they should be protected by rights
# -------
# * Perspective + keywords: Animals have rights. We are at the top of the animal hierarchy and should treat other animals accordingly in order to further our own species.
# -------
# * Perspective + keywords: Animals have rights. We only have indirect duties to animals
# -------
# * Perspective + keywords: Animals have rights. Animals have no interests or rationality
# -------
# * Perspective + keywords: Animals have rights. Most rights have no bearing for animals
# -------
# * Perspective + keywords: Proportional representation is necessary. PR produces fairer results
# -------
# * Perspective + keywords: Proportional representation is necessary. Coalition government is a good thing.
# -------
# * Perspective + keywords: Proportional representation is necessary. PR increases political engagement which benefits society.
# -------
# * Perspective + keywords: Proportional representation is necessary. PR leads to weaker government.
# -------
# * Perspective + keywords: Proportional representation is necessary. PR creates an unfair balance of power.
# -------
# * Perspective + keywords: Proportional representation is necessary. PR decreases political engagement.
# -------
# * Perspective + keywords: Proportional representation is necessary. The link between constituencies and Members of Parliament is important.
# -------
# * Perspective + keywords: Proportional representation is necessary. Extremist parties will rise under PR.
# -------
# * Perspective + keywords: There must be a child curfews. Curfews also have an important role in the protection of vulnerable children
# -------
# * Perspective + keywords: There must be a child curfews. A curfew is practical.
# -------
# * Perspective + keywords: There must be a child curfews. It is best for children to be at home in the evening.
# -------
# * Perspective + keywords: There must be a child curfews. Curfews are counter-productive.
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. The unauthorised downloading of copyrighted material should be addressed and prevented by the state
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. A graduated response will be an effective deterrent
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. A graduated response is the fairest way to enforce copyright legislation
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. The graduate response policy constitutes an invasion of privacy by the state
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. ISP will not cooperate with a graduated response policy
# -------
# * Perspective + keywords: It is important to use a graduated response to combat unauthorised file-sharing of copyrighted material. The graduated response is a violation of the basic right to due process
# -------
# * Perspective + keywords: Internet access is a human right. The right to internet access fills a gap in traditional human rights.
# -------
# * Perspective + keywords: Internet access is a human right. Internet access is a necessary part of the right to freedom of information and expression.
# -------
# * Perspective + keywords: Internet access is a human right. Internet access is a commodity not a human right.
# -------
# * Perspective + keywords: Internet access is a human right. Internet access is an enabler of rights not a right in itself.
# -------
# * Perspective + keywords: Internet access is a human right. Internet access cannot be a human right when it is not available to all.
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. We all have an obligation to help maintain freedom of speech.
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. Providing secure channels is the easiest way to help dissidents and democracy activists
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. Funding technologies to evade censorship could have immense benefits for very little cost
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. Violation of Sovereignty
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. Funds could be better spent on helping development
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. Evading censorship is already possible and censorship does not prevent the use of the internet.
# -------
# * Perspective + keywords: It is important to use foreign aid funds to research and distribute software that allows bloggers and journalists in non-democratic countries to evade censorship and conceal their online activities. This will needlessly antagonise non-democratic countries
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). Piracy in an Internet age.
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). ACTA promotes medical research
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). ACTA is needed to protect brands
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). ACTA is anti-democratic
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). Creativity will suffer if ACTA is brought in
# -------
# * Perspective + keywords: Ratify the Anti-Counterfeiting Trade Agreement (ACTA). ACTA attacks free software and privatises data
# -------
# * Perspective + keywords: Governments be allowed to disrupt Internet service on grounds of national security. Disrupting internet service is a form of repression.
# -------
# * Perspective + keywords: A new global body, the United Nations Committee for Internet Related Policies, take over internet governance. Internet governance must be multinational
# -------
# * Perspective + keywords: A new global body, the United Nations Committee for Internet Related Policies, take over internet governance. Governments not ‘civil society’ must be in control of internet governance
# -------
# * Perspective + keywords: A new global body, the United Nations Committee for Internet Related Policies, take over internet governance. The internet should be governed in the interests of freedom
# -------
# * Perspective + keywords: A new global body, the United Nations Committee for Internet Related Policies, take over internet governance. The status quo has been very successful; don’t fix something that is not broken.
# -------
# * Perspective + keywords: The net neutrality legislation has to be supported. Risk of a two-tier Internet
# -------
# * Perspective + keywords: The net neutrality legislation has to be supported. Incentivise ISPs to provide more data capacity
# -------
# * Perspective + keywords: The net neutrality legislation has to be supported. Allow ISPs to monitor and remove illegal or unwanted data
# -------
# * Perspective + keywords: There should be a presumption in favour of publication for information held by public bodies. If public bodies do not have an obligation to publish information, there will always be a temptation to find any available excuses to avoid transparency.
# -------
# * Perspective + keywords: There should be a presumption in favour of publication for information held by public bodies. Considering the amount of data governments produce, compelling them to publish all of it would be counterproductive as citizens would be swamped.
# -------
# * Perspective + keywords: There should be a presumption in favour of publication for information held by public bodies. It is reasonable that people have access to information that effects them personally but not information that relates to their neighbours’, employers’, former-partners’ or other citizens who maythose who work for public bodies.
# -------
# * Perspective + keywords: Goal line technology has to be adopted in football. Technology is more reliable than human judgement
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Athletes should be free to take risks when training and competing
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Controlling, rather than ignoring, performance enhancing substances will improve competitive standards in sport
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Drugs will undermine the central philosophy of sport
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Permitting the use of performace enhancers would have a coercive effect on athletes who would otherwise avoid drug use
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Protecting the health of athletes
# -------
# * Perspective + keywords: permit the use of performance enhancing drugs in professional sports. Protecting young and vulnerable athletes
# -------
# * Perspective + keywords: All nations should ban bullfighting. Bullfighting is a form of animal torture
# -------
# * Perspective + keywords: All nations should ban bullfighting. Harming animals for entertainment is immoral
# -------
# * Perspective + keywords: All nations should ban bullfighting. Bullfighting is too dangerous to humans to justify
# -------
# * Perspective + keywords: All nations should ban bullfighting. Bullfighting is an art-form and an important cultural tradition
# -------
# * Perspective + keywords: All nations should ban bullfighting. Bullfighting is no more harmful than the alternatives for bulls and cows
# -------
# * Perspective + keywords: All nations should ban bullfighting. Bullfighting is economically important for some regions
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Accurate calls should be the top priority, and instant replay helps provide them
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. It’s not possible to get every call right, so instant replay is a necessary supplement to umpires’ skill
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Instant replay will actually enhance umpires’ stature
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Instant replay will place the focus of the game where it belongs—on the players, not the umpires
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. With more accurate calls come more legitimate outcomes to games
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Instant replay will take too long
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Instant replay will take the human element out of baseball
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Tradition demands that this instant replay not be used
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Many plays don’t lend themselves to video review
# -------
# * Perspective + keywords: Instant Replay Should Be Used in Major League Baseball. Instant replay might be deceptive or inconclusive
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. This type of music is degrading to everyone, not just women.
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. Music depicting violence to women causes and sustains the cycle of violence.
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. Music depicting violence against women encourages men (and women) not to respect women.
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. It would be highly impractical to ban this music glorifying violence.
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. To ban this type of music encourages the viewing of women as helpless, victim figures.
# -------
# * Perspective + keywords: The music that glorifies violence against women should be banned. The 'Slippery-Slope' Argument
# -------
# * Perspective + keywords: It is crucial to explore the universe. The 'space race' fuels nationalistic sentiment and antagonism
# -------
# * Perspective + keywords: It is crucial to explore the universe. The cost of space exploration exceeds the positive benefits
# -------
# * Perspective + keywords: It is crucial to explore the universe. Space exploration takes resources away from more worthy causes
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Marriage is about more than procreation, therefore gay couples should not be denied the right to marry due to their biology.
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Gay couples should be able to take advantage of the fiscal and legal benefits of marriage
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Gay marriage is good for society
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. It is discriminatory to refuse gay couples the right to marry
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Gay marriage undermines the institution of marriage, leading to an increase in out of wedlock births and divorce rates
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Marriage should be between a man and a woman
# -------
# * Perspective + keywords: Gay couples should be allowed to marry. Marriage is a religious institution, and the major world religions frown upon homosexuality
# -------
# * Perspective + keywords: The Catholic Church is justified in forbidding the use of barrier methods of contraception. The Catholic Church believes that any limitation of procreation is against God.
# -------
# * Perspective + keywords: The Catholic Church is justified in forbidding the use of barrier methods of contraception. Protects people from spending eternity in Hell.
# -------
# * Perspective + keywords: The Catholic Church is justified in forbidding the use of barrier methods of contraception. Promotes image of Catholic Church as uncaring and stubborn.
# -------
# * Perspective + keywords: Atheism is the only way. Entirely natural theories can adequately explain the existence and development of the Universe and all it contains, making God irrelevant to the discussion of reality:
# -------
# * Perspective + keywords: Atheism is the only way. If there is a benevolent deity, then there should not be the kinds of evil observable in the world and He would likely show more interest in His creation than He appears to have done so far:
# -------
# * Perspective + keywords: Atheism is the only way. If there were a God there would be irrefutable evidence of His existence and people would feel compelled to belief by the fact of it:
# -------
# * Perspective + keywords: Atheism is the only way. The nature of God as it is conventionally described is logically contradictory:
# -------
# * Perspective + keywords: Atheism is the only way. In the absence of positive evidence for the existence of God the rational position is agnosticism, not atheism:
# -------
# * Perspective + keywords: Atheism is the only way. The complexity of the universe and of life cannot be explained by atheism:
# -------
# * Perspective + keywords: Anarchism is a valuable political ideology. Even in societies with a state, anarchist groups provide a voice for the oppressed.
# -------
# * Perspective + keywords: Anarchism is a valuable political ideology. Anarchy has nothing to contribute but violence.
# -------
# * Perspective + keywords: Anarchism is a valuable political ideology. Anarchist Communities have a very poor track record.
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. Imposing democracy can be a way to support individuals unable to fight for democracy themselves.
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. Promoting democracy promotes peace.
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. Because democracy is the best form of government, it is not wrong-- and indeed may even be our obligation-- to bring it to those who do not have it.
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. Democracy by its very nature cannot be imposed.
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. The imposition of democracy violates national sovereignty
# -------
# * Perspective + keywords: Democracy has to be imposed, if needed. Attempting to impose democracy may escalate conflict.
# -------
# * Perspective + keywords: Capitalism is better than socialism. The capitalist society enhances personal freedom
# -------
# * Perspective + keywords: Capitalism is better than socialism. Socialism leads to a more humane equal society
# -------
# * Perspective + keywords: Capitalism is better than socialism. Socialism provides a more sustainable way of living
# -------
# * Perspective + keywords: Capitalism is better than socialism. Socialism is a more secure system than the free market in Capitalism
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC is the best way to prosecute serious crimes because of its permanence; individual tribunals are not enough.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. If supported, the ICC will set a precedent and deter leaders from committing crimes against humanity.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC will prosecute leaders who commit the most severe crimes and give them their due.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC is the most suited towards the rising nature of crimes in a globalizing world.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. Efforts to strengthen the ICC will promote global cooperation, norms against crimes, and international stability.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC interferes with national operations (both military and humanitarian) because of how loosely the Rome Statue can be interpreted.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC does not have enough checks on prosecutorial powers, inviting prosecutorial abuse.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC has no real enforcement mechanism and cannot be a force for good if it has no way of ensuring prosecution.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC is not democratic in nature and is likely to be used as a political tool by powerful nations.
# -------
# * Perspective + keywords: The International Criminal Court is a force for good. The ICC infringes upon national sovereignty by inherently implying that there is a higher court nations must answer to.
# -------
# * Perspective + keywords: A common EU foreign policy should be favored. The EU has already been unifying on multiple fronts, this is just a step in the same direction.
# -------
# * Perspective + keywords: A common EU foreign policy should be favored. The fact that it is a Representative highlights the fact that the EU is based on consultation and consensus, and that is a positive thing.
# -------
# * Perspective + keywords: A common EU foreign policy should be favored. The post of a High Representative is merely a shadow of what it should have been, and its failure shows the EU's inability to consolidate foreign policy.
# -------
# * Perspective + keywords: A common EU foreign policy should be favored. The previous arrangement of having two foreign policy centers (in the Commission and in the Council) was arguably inefficient, but consolidating these into a single office-holder has created more complexity and at significantly greater expense.
# -------
# * Perspective + keywords: A common EU foreign policy should be favored. There have been tests on the EU's ability to create a common foreign policy that it has failed.
# -------
# * Perspective + keywords: The United Nations Security Council should be expanded. A rise in UN membership should be reflected also in an increase in Security Council members.
# -------
# * Perspective + keywords: The United Nations Security Council should be expanded. By giving five more countries veto power, the Council could come to a stalemate.
# -------
# * Perspective + keywords: The United Nations Security Council should be expanded. A UNSC reform is very hard to achieve due to the many different interests and demands.
# -------
# * Perspective + keywords: The United Nations Security Council should be expanded. The bulk of operations approved by the Security Council are financed by industrialised nations.
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Smokers are a drain on economic resources
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying access to healthcare for smokers would act as a deterrent, discouraging smokers
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. As smokers have a higher chance of harm from surgery due to complications arising from their habit, it is more efficient to prioritize non-smokers
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying healthcare to smokers is impractical
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying access to healthcare for smokers will lead to thousands of people being turned away and potentially dying from preventable illnesses
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying access to healthcare for smokers will hurt the economy
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying healthcare to smokers alone is victimization
# -------
# * Perspective + keywords: Smokers should be denied access to state healthcare. Denying healthcare to smokers is a restriction on people's liberties
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. Exposing non-smokers to second-hand smoke goes against their rights.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. This ban would lower healthcare costs.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. This ban would encourage smokers to smoke less or give up smoking altogether.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. This ban would be easy to introduce.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. This ban would be difficult to enforce.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. Smokers have a right to enjoy themselves.
# -------
# * Perspective + keywords: Smoking in public spaces should be banned. This ban would put many pubs, clubs, etc. out of business.
# -------
# * Perspective + keywords: Cannabis should be legalised. People should be allowed to do whatever they want to their own bodies
# -------
# * Perspective + keywords: Cannabis should be legalised. Alcohol and tobacco are more harmful drugs, yet remain legal.
# -------
# * Perspective + keywords: Cannabis should be legalised. If cannabis was legalized, it could be regulated
# -------
# * Perspective + keywords: Cannabis should be legalised. Cannabis opens the mind in a positive and beneficial manner
# -------
# * Perspective + keywords: Cannabis should be legalised. Cannabis is a gateway drug
# -------
# * Perspective + keywords: Cannabis should be legalised. Uncertainty over the effects of cannabis means it is best to be prudent
# -------
# * Perspective + keywords: Cannabis should be legalised. Cannabis is harmful
# -------
# * Perspective + keywords: Music containing lyrics that glorify violent and criminal lifestyles should be banned. Classification, not censorship
# -------
# * Perspective + keywords: Music containing lyrics that glorify violent and criminal lifestyles should be banned. Defending hip hop artists’ right to free speech
# -------
# * Perspective + keywords: Music containing lyrics that glorify violent and criminal lifestyles should be banned. A ban will be ineffective
# -------
# * Perspective + keywords: The leaking of military documents by Anat Kamm was justified. It is right that illegal acts by the state be exposed
# -------
# * Perspective + keywords: The leaking of military documents by Anat Kamm was justified. The public have a right to know what is committed in their name
# -------
# * Perspective + keywords: The leaking of military documents by Anat Kamm was justified. The military can only be held to account if there is transparency
# -------
# * Perspective + keywords: The leaking of military documents by Anat Kamm was justified. Leaking military secrets puts lives in danger
# -------
# * Perspective + keywords: Users of extremist websites should be punished. There needs to be a deterrent against those thinking of visiting extremist websites
# -------
# * Perspective + keywords: Users of extremist websites should be punished. The internet is an echo chamber that will confirm extremists in their views if not stopped
# -------
# * Perspective + keywords: Users of extremist websites should be punished. Criminalisation will not stop radicalisation
# -------
# * Perspective + keywords: Users of extremist websites should be punished. Criminalisation creates more problems than it solves
# -------
# * Perspective + keywords: Users of extremist websites should be punished. Freedom of expression is a fundamental human right.
# -------
# * Perspective + keywords: India’s Ban on the Satanic Verses is justified. People have a right to choose their cultural values
# -------
# * Perspective + keywords: India’s Ban on the Satanic Verses is justified. Freedom of Speech is a Universal Right
# -------
# * Perspective + keywords: We should fear the power of government over the Internet. Regulating the Internet is a means for governments to spy on their citizens
# -------
# * Perspective + keywords: We should fear the power of government over the Internet. Internet regjulation is a euphemism for censorship
# -------
# * Perspective + keywords: We should fear the power of government over the Internet. Internet regulation is necessary to ensure a safe internet
# -------
# * Perspective + keywords: We should fear the power of government over the Internet. Internet regulation is necessary to ensure a working economy on the internet
# -------
# * Perspective + keywords: Religious freedom abroad should be one of the primary foreign policy concerns for any country. Religious pluralism creates a more tolerant and peaceful society
# -------
# * Perspective + keywords: The BBC should be free to blaspheme. This was a piece of art, advertised and described as such, those likely to be offended were quite welcome not to watch it.
# -------
# * Perspective + keywords: The BBC should be free to blaspheme. Tens of thousands of licence fee payers objected to this, ultimately they are the BBC’s key stakeholder and that view is worthy of respect.
# -------
# * Perspective + keywords: It makes sense to drive to an out of town to a shopping centre. Malls promote competition and serve consumers well
# -------
# * Perspective + keywords: It makes sense to drive to an out of town to a shopping centre. Out of town shopping malls offer a better shopping experience
# -------
# * Perspective + keywords: It makes sense to drive to an out of town to a shopping centre. Out of town retail developments are bad for the environment
# -------
# * Perspective + keywords: It makes sense to drive to an out of town to a shopping centre. Out of town malls damage town centres
# -------
# * Perspective + keywords: It makes sense to drive to an out of town to a shopping centre. Out of town centres damage local communities' identities
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Energy demands are increasing exponentially and nuclear power is the only renewable source capable of matching it
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Nuclear power is clean and emits significantly less CO2 than other renewable energy sources
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Nuclear power gives countries energy security and self-sufficiency
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Nuclear power is very expensive
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Promoting continued nuclear research is against our security interests
# -------
# * Perspective + keywords: Nuclear technology must be adopted. The supply of uranium needed for nuclear power is not actually unlimited, renewable or sustainable
# -------
# * Perspective + keywords: Nuclear technology must be adopted. Nuclear power is potentially extremely unsafe
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animals have a right not to be harmed
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animal research necessitates significant harm to the animals involved
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Research can be done effectively without experimenting on living creature
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animals' rights are of less moral worth than human rights
# -------
# * Perspective + keywords: Performing tests on animals must be banned. People would die and suffer needlessly under such a policy
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animal research is necessary for the development of truly novel substances
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animal research is only used where other research methods are not suitable
# -------
# * Perspective + keywords: Performing tests on animals must be banned. Animals involved in animal research are mostly well treated.
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. Private universities are needed to increase the number of places for students.
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. The introduction of more private universities would increase the quality of education by allowing open competition
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. The privatisation of universities encourages course-diversity and provides for students are individuals, not cattle
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. Allowing universities to be guided by an invisible hand does more harm than good
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. Private Universities would risk reducing the quality of university degrees.
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. This will increase the perception that universities are just for the rich
# -------
# * Perspective + keywords: Private universities in the UK must be encouraged. Private universities would increase the divide between the rich and poor
# -------
# * Perspective + keywords: History has no place in the classroom. History should be left for those intellectual capable of understanding its limitations, and therefore not taught at school
# -------
# * Perspective + keywords: History has no place in the classroom. History teaching will reflect the erroneous preconceptions and aims of those who set the curriculum
# -------
# * Perspective + keywords: History has no place in the classroom. History lessons can be used as state-sponsored propaganda, distorting the events of the past
# -------
# * Perspective + keywords: History has no place in the classroom. Teaching history ensures that events of the past are not forgotten, and lessons are learned
# -------
# * Perspective + keywords: History has no place in the classroom. Historical facts can be established to a sufficient degree to be taught to schoolchildren
# -------
# * Perspective + keywords: History has no place in the classroom. History should be taught to school-children, they form an integral part of understanding oneself and one's nation
# -------
# * Perspective + keywords: History has no place in the classroom. History teaches useful skills applicable in other areas of education and life
# -------
# * Perspective + keywords: We must bring back corporal punishment. States' duty to avoid the use of force when solving social problems
# -------
# * Perspective + keywords: We must bring back corporal punishment. Flogging will be over-utilised, rehabilitation will be under-utilised
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. Hosting creates a 'feel-good' factor
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. Hosting stimulates regeneration in local areas
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. Any large expenditure in one area will stimulate regeneration. Considering that the cost of hosting the London 2012 Olympics is predicted at £2.375 billion, expected to rise far higher, regeneration is the least that can be expected as a le
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. Hosting has wide-reaching economic benefits
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. The bidding process is too long, tying up funds and land
# -------
# * Perspective + keywords: Hosting the Olympics is a good investment. Hosting is very expensive
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. There must be a maximum amount of performance that people are capable of, given rest and reward. To work people too long is to waste their potential.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. There should be a legally mandated ceiling on weekly working hours, because it creates employment.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. Introducing a cap on working hours would reduce unemployment.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. A maximum working week provides protection for workers.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. Policing such a policy creates its own set of problems for the society and costs for the economy
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. The market already limits worker hours when left to its own devices, no intrusion is required.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. There should be no legally mandated ceiling on weekly working hours as it limits economic growth.
# -------
# * Perspective + keywords: There should be a legally mandated ceiling on weekly working hours. Small and mid sized businesses cannot afford the extra costs involved in complying with such a policy.
# -------
# * Perspective + keywords: Gambling must be banned. Gambling is addictive and psychologically harmful
# -------
# * Perspective + keywords: Gambling must be banned. Gambling leads to the disintegration of families
# -------
# * Perspective + keywords: Gambling must be banned. Casinos are often used to mask criminal activity
# -------
# * Perspective + keywords: Gambling must be banned. Gambling is associated with other forms of addiction and harmful behaviour
# -------
# * Perspective + keywords: Gambling must be banned. It is impossible to effectively ban gambling
# -------
# * Perspective + keywords: Gambling must be banned. Casinos create positive economic effects in the communities that host them
# -------
# * Perspective + keywords: The sale of violent video games/censor violent video games should be illegal. Violent Video Games Cause Social Interaction Problems
# -------
# * Perspective + keywords: The sale of violent video games/censor violent video games should be illegal. Violent Video Games cause Violent Behaviour
# -------
# * Perspective + keywords: The sale of violent video games/censor violent video games should be illegal. Violent Video Games Prevent Violent Behaviour
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. The cartoons constitute a religiously motivated hate crime
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Violent reactions to the cartoons could have been predicted and should have been avoided
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Radical and anti western voices in Islamic communities gained authority and legitimacy as a result of the newspapers' actions
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Factors motivating publication of the cartoons
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Free expression and journalistic integrity
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Citizens of western liberal democracies should never be required to adhere to religious norms that they do not hold
# -------
# * Perspective + keywords: Danish newspapers should not have published cartoons depicting the Prophet Mohammed. Controversy, integration and civic participation
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. Life is more important than dignity
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. Anorectic patients are not able to make the decision for themselves.
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. Force feeding can help psychologically.
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. In the first instance, doctors should always act to keep a patient alive
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. Compulsory treatment is not a long term solution.
# -------
# * Perspective + keywords: We should force feed sufferers of Anorexia Nervosa. Force feeding strategies may cause physical harm
# -------
# * Perspective + keywords: English has to become the official language of the United States. The Identity and History of the United States are intrinsically linked to the English Language
# -------
# * Perspective + keywords: English has to become the official language of the United States. Bilingual Education is expensive and encourages balkanization
# -------
# * Perspective + keywords: English has to become the official language of the United States. Bilingual education hurts students
# -------
# * Perspective + keywords: English has to become the official language of the United States. It specifically denies a rich cultural heritage which is uniquely American of groups that spoke English but not as a first language
# -------
# * Perspective + keywords: English has to become the official language of the United States. Even within the United States people speak English differently
# -------
# * Perspective + keywords: English has to become the official language of the United States. The US has a long tradition of multiple languages
# -------
# ...
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. A 20 per cent cap is precisely what is required
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. Rebuttal: Understanding the problem outlined by Proposition
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. Rebuttal: On contradictions
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. The cap would impose a burden on people with good credit
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. The cap would deprive individuals with bad credit of possibility to borrow
# -------
# * Perspective + keywords: Interest rates on personal lending should be capped by law at 20%. Points on proposition's rebuttal to our arguments
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. Why these symbols are no different than verbal or written communication
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. Practical harm #1 - Encouraging extremist movements
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. Society is ready to live with Nazi and Soviet symbols
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. It would cause racial dissension
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. Why allowing the display of symbols enables the societies to deal with extremism better?
# -------
# * Perspective + keywords: Democracies should ban the display of communist and Nazi symbols. Summary of the opposition
# -------
# * Perspective + keywords: We should prize freedom over security and abolish anti-terrorism legislation. Anti-terrorism legislation undermines democracies
# -------
# * Perspective + keywords: We should prize freedom over security and abolish anti-terrorism legislation. Anti-terrorism legislation promotes abuse of the state
# -------
# * Perspective + keywords: We should prize freedom over security and abolish anti-terrorism legislation. Criminal justice system should be used for countering terrorism
# -------
# * Perspective + keywords: We should prize freedom over security and abolish anti-terrorism legislation. We don't regret the times anti-terrorism legislation has prevented attacks
# -------
# * Perspective + keywords: All drugs should be decriminalised. Decriminalising drugs will make them safer
# -------
# * Perspective + keywords: All drugs should be decriminalised. In addition to our fifth argument: Decriminalising drugs will make them safer
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade is not Free Trade
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade is not Free Trade (opposition as an example)
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade is not Fair Trade: Corporations reaps the benefit more than host country
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade is not Free Trade: Industry specialization is the price that outweighs the benefit of FTA
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade is not Fair Trade: Why countries should abandon Free Trade Agreements (Proposition Summary)
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Free Trade equals to Fine Fate
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. Limited trading capacity as a result of not being part of a free trade agreement.
# -------
# * Perspective + keywords: Poorer Countries Should Abandon Free Trade Agreements. All the countries in the world cannot be equally powerful, but they may be equally free.
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Why our plan achieves efficiency
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Why our plan achieves efficiency #2
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Benefit of Need-based Distribution
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Disastrous Impact on Other Transplants
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. The Responsibility of Those in the Medical Profession
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. The ethics of need-based and merit-based organ giving
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Last Rebuttal 1: On Status Quo and Ethical Issue
# -------
# * Perspective + keywords: Heavy drinkers should be denied liver transplants. Opposition's rebuttals to the Proposition's rebuttals
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. Life is ridiculous without a God.  Belief in God is the only sane thing we discuss.
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. God teaches forgiveness and love: an idea universally agreed upon as good.
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. Science can support the existance of God
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. According to Probability - a creator exists
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. Great physicists were deist
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. Teleological argument: Design
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. I AM WHO I AM
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. God is a concept dreamed up by optimistic people.
# -------
# * Perspective + keywords: There is a good case for stating that there is a God. 'God' is merely a concept designed to promote a set of values
# -------
# * Perspective + keywords: Pre-nuptial agreements should not be recognised in divorce courts. Pre-nuptial agreements reduce trauma associated with divorce
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Inadequacy of Alternative Categories
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Lack of legal category reinforces negative stereotypes
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Governments should not discourage people from their identity
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal: This is Not a Small Debate
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal: Democracy or Majoritarianism
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal: Stereotypes- Propagation and impact.
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. It creates a social backlash that damages substantive equality for homosexuals
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal 1: In defence of public opinion
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal 2: Moral and legal pluralism's rightful place
# -------
# * Perspective + keywords: Same-Sex Marriage Should Be Legal. Rebuttal 3: Homosexuality and moral agnosticism
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Justice, security, transperancy and human rights?
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. The case of M.I.T undergrad Dr.Aafia siddiqui
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. David Hicks' forced' to confess?
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Harvard Law's eight yes-arguments
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. maltreatment of refugees, displaced persons, bought and bagged prisoners, no longer in their homeland
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Convention Against Torture mauled
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. International War Crimes Tribunal
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Italy- U.S relations spoiled over Nasr's abduction
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. The opposition is ignoring our points? 'Foreign States CAN not be trusted.'
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. The principle of preemption and the need for expediency.
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. The rise of non-state actors and the responsibility of sovereignty of other states.
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Response to rebuttal to non-state actors point
# -------
# * Perspective + keywords: Leaders of countries that use extra-territorial rendition should be tried for war crimes. Response to rebuttal to proportion
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. It eliminates diseases and prevents them from returning
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Compulsory Immunization will create a herd immunity to protect those who cannot be vaccinated.
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. A child has a human right to be protected from preventable diseases from birth
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Vaccines are good not bad.
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Compulsory Immunizations are necessary to protect the right's of others.
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Refusal to vaccinate infringes upon the rights of the rest of the population
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Tyranny of the Majority
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. It gives up your indvidual rights as a united states citizen
# -------
# * Perspective + keywords: Public health concerns justify compulsory immunization. Herd Effect is Pointless
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Rich countries should actively recruit medical personnel from poor ones, and with this freedom must come the responsibility to reimburse them fully for the cost of their training.
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. The Rights of the Individual
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Plan promotes abuse by bad governments
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Plan creates more friction between richer and poorer countries
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Their plan is a failed Economic Model
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Welcome to the third world
# -------
# * Perspective + keywords: Rich countries should actively recruit medical personnel from poorer countries. Plan is a huge setback in human rights
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. Dictatorships regimes can be a path for countries move on from civil wars and focus on development
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. Dictatorship helps achieve social stability
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. Dictatorship outperforms democracy in growth and economic develpment
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. A dictatorship breeds order and it's a needed step for both development and liberal democracy
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. Dictatorship is a threat to diversity and multi ethnicity
# -------
# * Perspective + keywords: Dictatorship Is the Best Path to Development. Dictatorship transforms national policies into irregularities
# -------
# * Perspective + keywords: Religions Should Not Qualify as Charities. Some Emerging Religious Groups do Not Have the Political Connections to Qualify
# -------
# * Perspective + keywords: Net Neutrality – All Internet Traffic Should Be Treated Equally. Net neutrality helps preserve democracy and free speech
# -------
# * Perspective + keywords: Net Neutrality – All Internet Traffic Should Be Treated Equally. A government that ensures net neutrality is one that violates principles of freedom.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Strikes Make the United States Safer by Destroying Terrorist Networks Internationally.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drones Result in Fewer Civilian Fatalities than Other Weapons.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drones Keep US Military Personnel Safer
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Use is Cheaper than Engaging in Ground or Manned Aerial Combat
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Strikes Are Legal under International Law
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Strikes Are Legal under US Law
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Strikes Are Carried Out with the support of Local Governments and Make Those Countries Safer.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. The US cannot Risk Lagging Behind the Rest of the World in the Development of These Technologies.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. Drone Operators Have a Lower Risk for PTSD than Other Military Personnel.
# -------
# * Perspective + keywords: Drones Should Be Used to Take Out Enemy Combatants. The Majority of Americans Support Drone Strikes
# -------
# * Perspective + keywords: We Should Have a Quota for Women on Corporate Boards. Women are Under Represented on Corporate Boards
# -------
# * Perspective + keywords: We Should Have a Quota for Women on Corporate Boards. Diversity Makes Business Better
# -------
# * Perspective + keywords: We Should Have a Quota for Women on Corporate Boards. Quotas are Inherently Helpful
# -------
# * Perspective + keywords: We Should Have a Quota for Women on Corporate Boards. Putting a Quota in Place Would Help Women
